# %%
import jax
import jax.numpy as jnp
import jax.scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from functools import partial

import blackjax

from ripple.waveforms import IMRPhenomXAS
from ripple import ms_to_Mc_eta

from fastprogress import progress_bar

import blackjax

from pycbc.catalog import Merger
from pycbc.filter import resample_to_delta_t, highpass
from pycbc.psd import interpolate, inverse_spectrum_truncation
from pycbc.waveform import get_fd_waveform
from pycbc.filter import matched_filter, sigmasq, get_cutoff_indices 

from jax.config import config
config.update("jax_debug_nans", True)

jax.config.update("jax_enable_x64", True)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
data = {"L1": jnp.load("/users/sgreen/gwtuna/LVK/Paper/BBHSearch/P.E./L1_data.npy")}#, "H1": jnp.load("H1_data.npy")}
freqs = jnp.load("/users/sgreen/gwtuna/LVK/Paper/BBHSearch/P.E./L1_freqs.npy")
psd = {"L1": jnp.load("/users/sgreen/gwtuna/LVK/Paper/BBHSearch/P.E./L1_psd.npy")}#, "H1": jnp.load("H1_psd.npy")}

# %%
chi1 = 0.0
chi2 = 0.0
tc = 1126259462
phic = jnp.pi/2
dist_mpc = 100.
inclination = jnp.pi/2

# %%
def log_likelihood(mchirp, eta, fref=20.0, freqs=freqs, psd=psd, data=data, chi1=chi1, chi2=chi2, tc=tc, phic=phic, dist_mpc=dist_mpc, inclination=inclination):
#    hp, hc = waveform_generator(
#        freqs, mchirp, eta, chi1, chi2, tc, phic, dist_mpc, inclination,
#    )
    
    theta = jnp.array([mchirp, eta, chi1, chi2, tc, phic, dist_mpc, inclination])
    hp, hc = IMRPhenomXAS.gen_IMRPhenomXAS_polar(freqs, theta, fref)
    d_inner_h = 0.
    optimal_snr_squared = 0.
    for ifo in data.keys():
        if ifo == "L1":
            fp = -0.456852978678261
            fc = 0.36204310587763466
        else:
            fp = 0.45529254427236665
            fc = -0.6283981252126967
        h = hp*fp + hc*fc
        h_star = jnp.conj(h)
        integrand = jnp.nan_to_num(h_star * data[ifo] / psd[ifo], 0.)
        d_inner_h += 4.0 / 32.0 * jnp.sum(integrand)
        integrand = jnp.nan_to_num(h_star * h / psd[ifo], 0.)
        optimal_snr_squared += (4.0 / 32.0 * jnp.sum(integrand)).real
    log_l = d_inner_h.real - optimal_snr_squared / 2
    print(type(log_l.real))
    return log_l.real

# %%
#my_log_likelihood = partial(log_likelihood, freqs, psd, data)

# %%
def log_probability(mchirp, eta, fref=20.0, freqs=freqs, psd=psd, data=data, chi1=chi1, chi2=chi2, tc=tc, phic=phic, dist_mpc=dist_mpc, inclination=inclination):
    return log_likelihood(mchirp, eta, fref, freqs, psd, data, chi1, chi2, tc, phic, dist_mpc, inclination)

# %%
logdensity = lambda a: log_probability(**a)

# %%
inv_mass_matrix = np.array([0.0000001, 0.00000001])
num_integration_steps = 1e-5
step_size = 1e-5

nuts = blackjax.nuts(logdensity, step_size, inv_mass_matrix)
#hmc = blackjax.hmc(logdensity, step_size, inv_mass_matrix, num_integration_steps)

# %%
initial_position = {"mchirp": 30.0, "eta": 0.15}
initial_state = nuts.init(initial_position)
initial_state
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/pjit.py", line 1252, in _pjit_call_impl
#     return compiled.unsafe_call(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/profiler.py", line 314, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py", line 1920, in __call__
#     dispatch.check_special(self.name, arrays)
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/dispatch.py", line 436, in check_special
#     _check_special(name, buf.dtype, buf)
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/dispatch.py", line 441, in _check_special
#     raise FloatingPointError(f"invalid value (nan) encountered in {name}")
# FloatingPointError: invalid value (nan) encountered in jit(fn)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 173, in _run_module_as_main
#   File "<frozen runpy>", line 65, in _run_code
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ipykernel_launcher.py", line 0, in <module>
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/traitlets/config/application.py", line 984, in launch_instance
#     @classmethod
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 693, in start
#     def start(self):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 194, in start
#     def start(self) -> None:
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/asyncio/base_events.py", line 593, in run_forever
#     def run_forever(self):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/asyncio/base_events.py", line 1845, in _run_once
#     def _run_once(self):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/asyncio/events.py", line 78, in _run
#     def _run(self):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 501, in dispatch_queue
#     async def dispatch_queue(self):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 487, in process_one
#     async def process_one(self, wait=True):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 357, in dispatch_shell
#     async def dispatch_shell(self, msg):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 684, in execute_request
#     async def execute_request(self, stream, ident, parent):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 328, in do_execute
#     async def do_execute(
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 529, in run_cell
#     def run_cell(self, *args, **kwargs):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2973, in run_cell
#     def run_cell(
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3015, in _run_cell
#     def _run_cell(
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 120, in _pseudo_sync_runner
#     def _pseudo_sync_runner(coro):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3114, in run_cell_async
#     async def run_cell_async(
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3346, in run_ast_nodes
#     async def run_ast_nodes(
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3469, in run_code
#     async def run_code(self, code_obj, result=None, *, async_=False):
#
#   File "/tmp/ipykernel_15523/2851506802.py", line 0, in <module>
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/blackjax/mcmc/nuts.py", line 229, in init_fn
#     def init_fn(position: ArrayLikeTree):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/blackjax/mcmc/hmc.py", line 82, in init
#     def init(position: ArrayLikeTree, logdensity_fn: Callable):
#
#   File "/tmp/ipykernel_15523/1082511666.py", line 1, in <lambda>
#     logdensity = lambda a: log_probability(**a)
#
#   File "/tmp/ipykernel_15523/3166638172.py", line 1, in log_probability
#     def log_probability(mchirp, eta, fref=20.0, freqs=freqs, psd=psd, data=data, chi1=chi1, chi2=chi2, tc=tc, phic=phic, dist_mpc=dist_mpc, inclination=inclination):
#
#   File "/tmp/ipykernel_15523/3047686801.py", line 1, in log_likelihood
#     def log_likelihood(mchirp, eta, fref=20.0, freqs=freqs, psd=psd, data=data, chi1=chi1, chi2=chi2, tc=tc, phic=phic, dist_mpc=dist_mpc, inclination=inclination):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 1382, in gen_IMRPhenomXAS_polar
#     def gen_IMRPhenomXAS_polar(f: Array, params: Array, f_ref: float):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 1350, in gen_IMRPhenomXAS
#     def gen_IMRPhenomXAS(f: Array, params: Array, f_ref: float):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 1302, in _gen_IMRPhenomXAS
#     def _gen_IMRPhenomXAS(
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 715, in Phase
#     def Phase(f: Array, theta: Array, phase_coeffs: Array) -> Array:
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 17, in get_inspiral_phase
#     def get_inspiral_phase(fM_s: Array, theta: Array, phase_coeffs: Array) -> Array:
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py", line 246, in deferring_binary_op
#     def deferring_binary_op(self, other):
#
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/numpy/ufuncs.py", line 94, in fn
#     def fn(x1, x2, /):
#
# jax._src.source_info_util.JaxStackTraceBeforeTransformation: FloatingPointError: invalid value (nan) encountered in jit(mul)
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_15523/2851506802.py", line 2, in <module>
#     initial_state = nuts.init(initial_position)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/blackjax/mcmc/nuts.py", line 230, in init_fn
#     return cls.init(position, logdensity_fn)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/blackjax/mcmc/hmc.py", line 83, in init
#     logdensity, logdensity_grad = jax.value_and_grad(logdensity_fn)(position)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/traceback_util.py", line 166, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/api.py", line 735, in value_and_grad_f
#     ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/api.py", line 2258, in _vjp
#     out_primal, out_vjp = ad.vjp(
#                           ^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/interpreters/ad.py", line 139, in vjp
#     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/interpreters/ad.py", line 128, in linearize
#     jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/profiler.py", line 314, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py", line 771, in trace_to_jaxpr_nounits
#     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/linear_util.py", line 166, in call_wrapped
#     ans = self.f(*args, **dict(self.params, **kwargs))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_15523/1082511666.py", line 1, in <lambda>
#     logdensity = lambda a: log_probability(**a)
#                            ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_15523/3166638172.py", line 2, in log_probability
#     return log_likelihood(mchirp, eta, fref, freqs, psd, data, chi1, chi2, tc, phic, dist_mpc, inclination)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_15523/3047686801.py", line 7, in log_likelihood
#     hp, hc = IMRPhenomXAS.gen_IMRPhenomXAS_polar(freqs, theta, fref)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 1404, in gen_IMRPhenomXAS_polar
#     h0 = gen_IMRPhenomXAS(f, params, f_ref)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 1375, in gen_IMRPhenomXAS
#     h0 = _gen_IMRPhenomXAS(
#          ^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 1325, in _gen_IMRPhenomXAS
#     Psi = Phase(f, theta_intrinsic, phase_coeffs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 739, in Phase
#     phi_Ins = get_inspiral_phase(fM_s, theta, phase_coeffs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/ripple/waveforms/IMRPhenomXAS.py", line 310, in get_inspiral_phase
#     + phi5L * (fM_s ** (5.0 / 3.0)) * jnp.log(fM_s)
#       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 649, in __mul__
#     def __mul__(self, other): return self.aval._mul(self, other)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py", line 251, in deferring_binary_op
#     return binary_op(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/traceback_util.py", line 166, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/pjit.py", line 238, in cache_miss
#     outs, out_flat, out_tree, args_flat = _python_pjit_helper(
#                                           ^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/pjit.py", line 185, in _python_pjit_helper
#     out_flat = pjit_p.bind(*args_flat, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 2592, in bind
#     return self.bind_with_trace(top_trace, args, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 363, in bind_with_trace
#     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/interpreters/ad.py", line 315, in process_primitive
#     primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/pjit.py", line 1544, in _pjit_jvp
#     outputs = pjit_p.bind(
#               ^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 2592, in bind
#     return self.bind_with_trace(top_trace, args, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 363, in bind_with_trace
#     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py", line 211, in process_primitive
#     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/pjit.py", line 1623, in _pjit_partial_eval
#     all_known_outs = pjit_p.bind(*known_inputs, **known_params)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 2592, in bind
#     return self.bind_with_trace(top_trace, args, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 363, in bind_with_trace
#     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 817, in process_primitive
#     return primitive.impl(*tracers, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/pjit.py", line 1256, in _pjit_call_impl
#     _ = core.jaxpr_as_fun(jaxpr)(*args)  # may raise, not return
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 228, in jaxpr_as_fun
#     return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 426, in eval_jaxpr
#     ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 360, in bind
#     return self.bind_with_trace(find_top_trace(args), args, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 363, in bind_with_trace
#     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/core.py", line 817, in process_primitive
#     return primitive.impl(*tracers, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/dispatch.py", line 129, in apply_primitive
#     return compiled_fun(*args)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/dispatch.py", line 211, in <lambda>
#     return lambda *args, **kw: compiled(*args, **kw)[0]
#                                ^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/profiler.py", line 314, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py", line 1920, in __call__
#     dispatch.check_special(self.name, arrays)
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/dispatch.py", line 436, in check_special
#     _check_special(name, buf.dtype, buf)
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/jax/_src/dispatch.py", line 441, in _check_special
#     raise FloatingPointError(f"invalid value (nan) encountered in {name}")
# FloatingPointError: invalid value (nan) encountered in jit(mul)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2102, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1310, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1199, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1071, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/ultratb.py", line 978, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/ultratb.py", line 878, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/IPython/core/ultratb.py", line 712, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "/mnt/lustre/shared_conda/envs/sgreen/PyCBCandOptuna/lib/python3.11/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
nuts_kernel = jax.jit(nuts.step)

# %%
def inference_loop(rng_key, kernel, initial_state, num_samples):
    @jax.jit
    def one_step(state, rng_key):
        state, _ = kernel(rng_key, state)
        return state, state

    keys = jax.random.split(rng_key, num_samples)
    _, states = jax.lax.scan(one_step, initial_state, keys)

    return states

# %%
# %%time
rng_key = jax.random.PRNGKey(0)
states = inference_loop(rng_key, nuts_kernel, initial_state, 10_000)

m_samples = states.position["mchirp"].block_until_ready()
b_samples = states.position["eta"].block_until_ready()
#scale_samples = jnp.exp(states.position["log_scale"])

# %%
fig, (ax, ax1) = plt.subplots(ncols=2, figsize=(15, 6))
ax.plot(m_samples)
ax.set_xlabel("Samples")
ax.set_ylabel("m")

ax1.plot(b_samples)
ax1.set_xlabel("Samples")
ax1.set_ylabel("b")

# %%
inv_mass_matrix = np.array([0.01, 0.01, 0.01])
step_size = 1e-3

nuts = blackjax.nuts(logdensity, step_size, inv_mass_matrix)

# %%
initial_position = {"m": -1.0, "b": 5.0, "log_f": jnp.log(0.5)}
initial_state = nuts.init(initial_position)
initial_state

# %%
# %%time
rng_key = jax.random.PRNGKey(0)
states = inference_loop(rng_key, nuts.step, initial_state, 4_000)

m_samples = states.position["m"].block_until_ready()
b_samples = states.position["b"].block_until_ready()
#loc_samples = states.position["loc"].block_until_ready()
#scale_samples = jnp.exp(states.position["log_scale"])

# %%
fig, (ax, ax1) = plt.subplots(ncols=2, figsize=(15, 6))
ax.plot(m_samples)
ax.set_xlabel("Samples")
ax.set_ylabel("m")

ax1.plot(b_samples)
ax1.set_xlabel("Samples")
ax1.set_ylabel("b")
